# %%
import urllib.error
import urllib.parse
import urllib.request

# %%
req = "https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=MSFT&interval=1min&apikey=demo"
with urllib.request.urlopen(req, timeout=15) as response:
    print(response.read())
# Out:
# b'{\n    "Meta Data": {\n        "1. Information": "Intraday (1min) prices and volumes",\n        "2. Symbol": "MSFT",\n        "3. Last Refreshed": "2018-07-19 12:28:00",\n        "4. Interval": "1min",\n        "5. Output Size": "Compact",\n        "6. Time Zone": "US/Eastern"\n    },\n    "Time Series (1min)": {\n        "2018-07-19 12:28:00": {\n            "1. open": "104.6900",\n            "2. high": "104.7100",\n            "3. low": "104.6700",\n            "4. close": "104.6991",\n            "5. volume": "31333"\n        },\n        "2018-07-19 12:27:00": {\n            "1. open": "104.7648",\n            "2. high": "104.7650",\n            "3. low": "104.6900",\n            "4. close": "104.6900",\n            "5. volume": "27519"\n        },\n        "2018-07-19 12:26:00": {\n            "1. open": "104.7760",\n            "2. high": "104.8000",\n            "3. low": "104.7600",\n            "4. close": "104.7700",\n            "5. volume": "11735"\n        },\n        
# ...
